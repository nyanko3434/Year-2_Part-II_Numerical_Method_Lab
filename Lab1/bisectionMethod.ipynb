# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
def _visualize_bisection(func, a, b, midpoints):
    x = np.linspace(a, b, 400)
    y = func(x)

    plt.figure(figsize=(10, 6))
    plt.plot(x, y, label='f(x)', color='blue')
    plt.axhline(0, color='black', linewidth=0.5)

    for i, c in enumerate(midpoints):
        plt.axvline(c, color='red', linestyle='--', alpha=0.3)
        plt.plot(c, func(c), 'ko')  # Mark the midpoint

    plt.title("Bisection Method Visualization")
    plt.xlabel("x")
    plt.ylabel("f(x)")
    plt.legend()
    plt.grid(True)
    plt.show()

# %%
#functions for bisectional method in Numerical Methods
def bisection(func, a, b, tol=1e-5, max_iter=100, visualize=True):
    if func(a) * func(b) >= 0:
        raise ValueError("Function values at the endpoints must have opposite signs.")
    
    iterations = []
    midpoints = []

    for i in range(max_iter):
        c = (a + b) / 2.0
        iterations.append(i)
        midpoints.append(c)

        if abs(func(c)) < tol or (b - a) / 2 < tol:
            if visualize:
                _visualize_bisection(func, a, b, midpoints)
            return c

        if func(c) * func(a) < 0:
            b = c
        else:
            a = c

    if visualize:
        _visualize_bisection(func, a, b, midpoints)
    
    raise ValueError("Maximum iterations reached without convergence.")

# %%
def bisection_with_steps(func, a, b, tol=1e-5, max_iter=100):

    if func(a) * func(b) >= 0:
        raise ValueError("Function values at the endpoints must have opposite signs.")
    
    print(f"Initial interval: [{a}, {b}]")
    
    for i in range(max_iter):
        c = (a + b) / 2.0  # Midpoint
        print(f"Iteration {i+1}: c = {c}, f(c) = {func(c)}")
        
        if abs(func(c)) < tol or (b - a) / 2 < tol:
            return c  # Root found
        
        if func(c) * func(a) < 0:
            b = c  # Root is in left half
            print(f"New interval: [{a}, {b}]")
        else:
            a = c  # Root is in right half
            print(f"New interval: [{a}, {b}]")
    
    raise ValueError("Maximum iterations reached without convergence.")

# %%
def func_one(x):
    return x**2 - 4

def func_two(x):
    return x**3 - x - 2

def func_three(x):
    return 3*x + 2

# %%
function_variable = func_one

try:
    root = bisection(function_variable, 0, 5, max_iter=1000)
    print(f"\n\nRoot found: {root}\n\n")
except ValueError as e:
    print(e)
# Out:
# Root found: 1.9999980926513672

# %%
function_variable = func_two
try:
    root = bisection_with_steps(function_variable, 1, 2, max_iter=1000)
    print(f"\n\nRoot found: {root}\n\n")
except ValueError as e:
    print(e)
# Out:
# Initial interval: [1, 2]
# Iteration 1: c = 1.5, f(c) = -0.125
# New interval: [1.5, 2]
# Iteration 2: c = 1.75, f(c) = 1.609375
# New interval: [1.5, 1.75]
# Iteration 3: c = 1.625, f(c) = 0.666015625
# New interval: [1.5, 1.625]
# Iteration 4: c = 1.5625, f(c) = 0.252197265625
# New interval: [1.5, 1.5625]
# Iteration 5: c = 1.53125, f(c) = 0.059112548828125
# New interval: [1.5, 1.53125]
# Iteration 6: c = 1.515625, f(c) = -0.034053802490234375
# New interval: [1.515625, 1.53125]
# Iteration 7: c = 1.5234375, f(c) = 0.012250423431396484
# New interval: [1.515625, 1.5234375]
# Iteration 8: c = 1.51953125, f(c) = -0.010971248149871826
# New interval: [1.51953125, 1.5234375]
# Iteration 9: c = 1.521484375, f(c) = 0.0006221756339073181
# New interval: [1.51953125, 1.521484375]
# Iteration 10: c = 1.5205078125, f(c) = -0.005178886465728283
# New interval: [1.5205078125, 1.521484375]
# Iteration 11: c = 1.52099609375, f(c) = -0.002279443317092955
# New interval: [1.52099609375, 1.521484375]
# Iteration 12: c = 1.521240234375, f(c) = -0.0008289058605441824
# New interval: [1.521240234375, 1.521484375]
# Iteration 13: c = 1.5213623046875, f(c) = -0.0001034331235132413
# New interval: [1.5213623046875, 1.521484375]
# Iteration 14: c = 1.52142333984375, f(c) = 0.0002593542519662151
# New interval: [1.5213623046875, 1.52142333984375]
# Iteration 15: c = 1.521392822265625, f(c) = 7.795631350404619e-05
# New interval: [1.5213623046875, 1.521392822265625]
# Iteration 16: c = 1.5213775634765625, f(c) = -1.2739467674549587e-05
# New interval: [1.5213775634765625, 1.521392822265625]
# Iteration 17: c = 1.5213851928710938, f(c) = 3.260815724592803e-05
#
#
# Root found: 1.5213851928710938

# %%
function_variable = func_three
try:
    root = bisection(function_variable, -10, 10)
    print(f"\n\nRoot found: {root}\n\n")
except ValueError as e:
    print(e)
# Out:
# Root found: -0.6666660308837891

# %%
function_variable = func_two
try:
    root = bisection(function_variable, -2, 2)
    print(f"\n\nRoot found: {root}\n\n")
except ValueError as e:
    print(e)
# Out:
# Root found: 1.5213851928710938
